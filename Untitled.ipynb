# %%
import json
import random
from tqdm import tqdm
from IPython.display import display, Markdown, Image

# 请确保使用正确的文件路径
json_file_path = "C:\\Users\\USER\\Desktop\\EXAM\\AWSMLP_QuestionBank.json"

# 使用UTF-8编码读取JSON文件
with open(json_file_path, 'r', encoding='utf-8') as json_file:
    data = json.load(json_file)

PRACTICE_MODE = False
correct = 0
total_questions = 4  # 根据你的JSON数据中的题目数量设置

# 随机选择题目数量（这里设置为总题数，因为total_questions应小于等于实际题数）
questions = random.sample(data["Questions"], total_questions)

for idx, question in enumerate(tqdm(questions)):
    display(Markdown(f"<h3>{question['question']}</h3>"))

    # 检查并显示所有图片
    if 'images' in question and question['images']:
        for image in question['images']:
            if image.strip():  # 如果图片路径不为空
                display(Image(filename=image))

    # 初始化选项列表
    options_with_letters = []

    # 显示选项，并添加到选项列表
    for i, option in enumerate(question["options"], start=1):
        option_letter = f"{chr(64+i)}"  # 将数字1, 2, 3, 4转换为A, B, C, D
        display(Markdown(f"<h4>{option_letter}. {option}</h4>"))
        options_with_letters.append((option_letter, option))

    # 提示用户输入答案
    my_answer = input("Enter your answer (A, B, C, or D) or type 'q' to end the quiz: ").strip().upper()

    # 如果用户选择退出
    if my_answer == 'Q':
        break

    # 检查用户答案是否正确
    if (my_answer, question["answer"]) in options_with_letters:
        correct += 1
        print("Correct!")
    else:
        print(f"Incorrect! The correct answer is: {question['answer']}")

    if PRACTICE_MODE:
        print("\n---")
        my_key = input("Press Enter to continue or type 'q' to quit:")
        if my_key.lower() == 'q':
            break

# 显示最终得分
print(f"You answered {idx + 1} questions and got {correct} correct. Score: {(correct / (idx + 1)) * 100:.2f}%")
# Out:
#  ... (more hidden) ...
# <h3>1. Which is true?</h3>
# <h4>A. The program prints t1 : 1 : t2 : 1: t1 : 2 : t2 : 2 : in random order.</h4>
# <h4>B. The program prints t1 : 1 : t2 : 1: t1 : 2 : t2 : 2 :</h4>
# <h4>C. The program prints t1 : 1 : t2 : 1: t1 : 1 : t2 : 1 : indefinitely.</h4>
# <h4>D. The program prints an exception.</h4>
# Enter your answer (A, B, C, or D) or type 'q' to end the quiz:  A
#  ... (more hidden) ...
# Correct!
# <h3>2. Which statement is true?</h3>
# <h4>A. IllegalStateException is thrown if a thread in waiting state is moved back to runnable.</h4>
# <h4>B. A thread in waiting state consumes CPU cycles.</h4>
# <h4>C. After the timed wait expires, the waited thread moves to the terminated state.</h4>
# <h4>D. A thread in waiting state must handle InterruptedException.</h4>
# Enter your answer (A, B, C, or D) or type 'q' to end the quiz:  C
#  ... (more hidden) ...
# Incorrect! The correct answer is: A thread in waiting state must handle InterruptedException.
# <h3>3. Daylight Saving Time (DST) is the practice of advancing clocks at the start of spring by one hour and adjusting them backward by one hour in autumn. Considering that in 2021, DST in Chicago (Illinois) ended on November 7th at 2 AM, and given the fragment: [image] What is the output?</h3>
# <h4>A. true 、true</h4>
# <h4>B. false、true</h4>
# <h4>C. true、false</h4>
# <h4>D. false、false</h4>
# Enter your answer (A, B, C, or D) or type 'q' to end the quiz:  q
#  ... (more hidden) ...
# You answered 3 questions and got 1 correct. Score: 33.33%
